# %%
#NETFLIX - Movies and TV Shows Prediction

# %%
# About the Dataset -

# This dataset consists of tv shows and movies available on Netflix.

# %%
#Aim : To analyse the data and various factors affecting the trend of Movies and Shows available on Netflix. Building a NETFLIX Movies and TV Shows Prediction Model based on the dataset.

# %%
# Content :

#   Import required libraries
#   Import the dataset
#   Data Exploration
#   Data Preprocessing
#   Data Analysis and Visualization
#   Spliting : training and testing dataset
#   Modeling

# %% [markdown]
# # Import the required libraries

# %%
import pandas as pd
import numpy as np   
import matplotlib.pyplot as plt  
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import the dataset

# %%
df = pd.read_csv('C:\\Users\\HP\\Desktop\\DA project\\netflix_titles.csv')

# %%
#Display the Dataset
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Data Exploration

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.director.unique()
# Out:
# array(['Kirsten Johnson', nan, 'Julien Leclercq', ..., 'Majid Al Ansari',
#        'Peter Hewitt', 'Mozez Singh'], dtype=object)

# %%
df.cast.unique()
# Out:
# array([nan,
#        'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng',
#        'Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabiha Akkari, Sofia Lesaffre, Salim Kechiouche, Noureddine Farihi, Geert Van Rampelberg, Bakary Diombera',
#        ...,
#        'Jesse Eisenberg, Woody Harrelson, Emma Stone, Abigail Breslin, Amber Heard, Bill Murray, Derek Graf',
#        'Tim Allen, Courteney Cox, Chevy Chase, Kate Mara, Ryan Newman, Michael Cassidy, Spencer Breslin, Rip Torn, Kevin Zegers',
#        'Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy'],
#       dtype=object)

# %% [markdown]
# # Data Preprossing

# %%
df.duplicated().sum() #check for duplicate value
# Out:
# 0

# %%
df.isna().sum() #null value
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
Perc_Missing_Values=(df.isna().sum()/df.shape[0])*100
Perc_Missing_Values
#Perc_Missing_Values[Perc_Missing_Values!=0]
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        29.908028
# cast             9.367549
# country          9.435676
# date_added       0.113546
# release_year     0.000000
# rating           0.045418
# duration         0.034064
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
Perc_Missing_Values.plot(kind="bar")
plt.title("Percentage of Missing Values")
plt.show()

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# The missing values and not required column :

# "show_id": Not that important. so i will be dropping this.
# "director": Percentage of missing values are more so I will be dropping this.
# "cast": there are too many diferent values so I will be dropping this.
# "country":Important variable hence we need to fix this.
# "date_added": It is important so I need to fix it.
# "rating": It is important so I need to fix it.
# "Description": Not that much Important.So i will be dropping this.
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#Drop (cast,director,show id,description) columns:

df.drop("cast",axis=1,inplace=True)
df.drop("director",axis=1,inplace=True)
df.drop("show_id",axis=1,inplace=True)
df.drop("description",axis=1,inplace=True)

# %%
#Fill the missing values:

df["country"]=df["country"].fillna(df["country"].mode()[0])
df["rating"]=df["rating"].fillna(df["rating"].mode()[0])

# %%
#Fix the Date_added Column:

df[df.date_added.isna()]
# Out:
#          type                                        title         country  \
# 6066  TV Show  A Young Doctor's Notebook and Other Stories  United Kingdom
# 6174  TV Show              Anthony Bourdain: Parts Unknown   United States
# 6795  TV Show                                      Frasier   United States
# 6806  TV Show                                      Friends   United States
# 6901  TV Show                              Gunslinger Girl           Japan
# 7196  TV Show                                     Kikoriki   United States
# 7254  TV Show                          La Familia P. Luche   United States
# 7406  TV Show                                        Maron   United States
# 7847  TV Show                                 Red vs. Blue   United States
# 8182  TV Show                 The Adventures of Figaro Pho       Australia
#
#      date_added  release_year rating    duration  \
# 6066        NaN          2013  TV-MA   2 Seasons
# ...

# %%
#We will drop those Rows.They are only 10 Rows .Becoz it is difficult to add date of those Rows

df=df[df["date_added"].notna()]

# %%
#Check the Cleaned dataset

df.isna().sum()
# Out:
# type            0
# title           0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# type            0
# title           0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# # Feature Engineering and Feature Extraction

# %%
df['date_added'].head
# Out:
# <bound method NDFrame.head of 0       September 25, 2021
# 1       September 24, 2021
# 2       September 24, 2021
# 3       September 24, 2021
# 4       September 24, 2021
#                ...
# 8802     November 20, 2019
# 8803          July 1, 2019
# 8804      November 1, 2019
# 8805      January 11, 2020
# 8806         March 2, 2019
# Name: date_added, Length: 8794, dtype: object>

# %%
df['year_added'] = df['date_added'].apply(lambda x: x.split(" ")[-1])
df['year_added'].head()
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 4    2021
# Name: year_added, dtype: object

# %%
df['month_added'] = df['date_added'].apply(lambda x: x.split(" ")[0])
df['month_added'].head()
# Out:
# 0    September
# 1    September
# 2    September
# 3    September
# 4    September
# Name: month_added, dtype: object

# %%
df['date_added'].head()
# Out:
# 0    September 25, 2021
# 1    September 24, 2021
# 2    September 24, 2021
# 3    September 24, 2021
# 4    September 24, 2021
# Name: date_added, dtype: object

# %%
df['date_month'] = df['date_added'].apply(lambda x: x.split(",")[-2])
df['date_month'].head()
# Out:
# 0    September 25
# 1    September 24
# 2    September 24
# 3    September 24
# 4    September 24
# Name: date_month, dtype: object

# %%
df['date_added_dates'] = df['date_month'].apply(lambda x: x.split(" ")[-1])
df['date_added_dates'].head()
# Out:
# 0    25
# 1    24
# 2    24
# 3    24
# 4    24
# Name: date_added_dates, dtype: object

# %%
df
# Out:
#          type                  title        country          date_added  \
# 0       Movie   Dick Johnson Is Dead  United States  September 25, 2021
# 1     TV Show          Blood & Water   South Africa  September 24, 2021
# 2     TV Show              Ganglands  United States  September 24, 2021
# 3     TV Show  Jailbirds New Orleans  United States  September 24, 2021
# 4     TV Show           Kota Factory          India  September 24, 2021
# ...       ...                    ...            ...                 ...
# 8802    Movie                 Zodiac  United States   November 20, 2019
# 8803  TV Show            Zombie Dumb  United States        July 1, 2019
# 8804    Movie             Zombieland  United States    November 1, 2019
# 8805    Movie                   Zoom  United States    January 11, 2020
# 8806    Movie                 Zubaan          India       March 2, 2019
#
#       release_year rating   duration  \
# 0             2020  PG-13     90 min
# ...

# %%
df.drop('date_added', axis='columns',inplace=True)
df.drop('date_month', axis='columns',inplace=True)

# %%
df
# Out:
#          type                  title        country  release_year rating  \
# 0       Movie   Dick Johnson Is Dead  United States          2020  PG-13
# 1     TV Show          Blood & Water   South Africa          2021  TV-MA
# 2     TV Show              Ganglands  United States          2021  TV-MA
# 3     TV Show  Jailbirds New Orleans  United States          2021  TV-MA
# 4     TV Show           Kota Factory          India          2021  TV-MA
# ...       ...                    ...            ...           ...    ...
# 8802    Movie                 Zodiac  United States          2007      R
# 8803  TV Show            Zombie Dumb  United States          2018  TV-Y7
# 8804    Movie             Zombieland  United States          2009      R
# 8805    Movie                   Zoom  United States          2006     PG
# 8806    Movie                 Zubaan          India          2015  TV-14
#
#        duration                                          listed_in year_added  \
# ...

# %%
df.replace({'TV Show': 0, 'Movie': 1}, df["type"]) #replace tv show with 0 and movie with 1
# Out:
#          type                  title        country  release_year rating  \
# 0       Movie   Dick Johnson Is Dead  United States          2020  PG-13
# 1     TV Show          Blood & Water   South Africa          2021  TV-MA
# 2     TV Show              Ganglands  United States          2021  TV-MA
# 3     TV Show  Jailbirds New Orleans  United States          2021  TV-MA
# 4     TV Show           Kota Factory          India          2021  TV-MA
# ...       ...                    ...            ...           ...    ...
# 8802    Movie                 Zodiac  United States          2007      R
# 8803  TV Show            Zombie Dumb  United States          2018  TV-Y7
# 8804    Movie             Zombieland  United States          2009      R
# 8805    Movie                   Zoom  United States          2006     PG
# 8806    Movie                 Zubaan          India          2015  TV-14
#
#        duration                                          listed_in year_added  \
# ...

# %%
df["rating"].unique() #list of unique rating
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# PG-13: Parental Guidance Suggested - Some material may be inappropriate for children under 13.
# TV-MA: Mature Audience - Content is specifically designed to be viewed by adults and may be unsuitable for children under 17.
# PG: Parental Guidance Suggested - Some material may not be suitable for children.
# TV-14: Parents Strongly Cautioned - Content may be unsuitable for children under 14.
# TV-PG: Parental Guidance Suggested - Some material may not be suitable for children under 7.
# TV-Y: All Children - Content is suitable for all ages.
# TV-Y7: Directed to Older Children - Content is suitable for children age 7 and above.
# R: Restricted - Restricted to viewers over the age of 17 (under 17 requires accompanying parent or adult guardian).
# TV-G: General Audience - All ages are admitted.
# G: General Audience - All ages are admitted.
# NC-17: No One 17 and Under Admitted - Content is not suitable for viewers under 17.
# NR: Not Rated - Content has not been assigned a specific rating.
# TV-Y7-FV: Directed to Older Children - Fantasy Violence - Similar to TV-Y7, but may contain more intense fantasy violence.
# UR: Unrated - Similar to "Not Rated," indicating that no official rating has been assigned to the content.
    
ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens', 
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}  #replacing ratings ages with some category (older kids-5 to 12 , adults-above 18years , teens-13 to 18 years , kids-below 5)

# %%
df['target_ages'] = df['rating'].replace(ratings_ages)  #replace the ratings with above category
df['target_ages'].unique()
# Out:
# array(['Teens', 'Adults', 'Older Kids', 'Kids'], dtype=object)

# %%
df
# Out:
#          type                  title        country  release_year rating  \
# 0       Movie   Dick Johnson Is Dead  United States          2020  PG-13
# 1     TV Show          Blood & Water   South Africa          2021  TV-MA
# 2     TV Show              Ganglands  United States          2021  TV-MA
# 3     TV Show  Jailbirds New Orleans  United States          2021  TV-MA
# 4     TV Show           Kota Factory          India          2021  TV-MA
# ...       ...                    ...            ...           ...    ...
# 8802    Movie                 Zodiac  United States          2007      R
# 8803  TV Show            Zombie Dumb  United States          2018  TV-Y7
# 8804    Movie             Zombieland  United States          2009      R
# 8805    Movie                   Zoom  United States          2006     PG
# 8806    Movie                 Zubaan          India          2015  TV-14
#
#        duration                                          listed_in year_added  \
# ...

# %% [markdown]
# # Exploratory Data Analysis and Visualization

# %%
#movie and tv show distribution
sns.countplot(x=df.type)
plt.title("Netflix Sources Distribution")
plt.show()

# %%
#country based on show 
countries=pd.crosstab(df["country"],["type"]).sort_values(by="type",ascending=False)
countries.head(10).plot(kind="bar")
plt.legend()
plt.title("COUNTRY WITH HIGHEST NUMBER OF SHOWS")
plt.show()

# %%
#percentage of movie and tv show
x=["Movies","TV Shows"]
plt.title("%AGE OF MOVIES AND TV SHOWS")
plt.pie(df["type"].value_counts(),labels=x,autopct="%1.1f%%")
plt.legend()
plt.show()

# %%
#label encoding-a process of assigning numerical labels to categorical data values.
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['target_ages'] = le.fit_transform(df["target_ages"])#adults is replaced by 0 , teens is replaced by 1 , older kids is replaced by 2 and kids is replaced by 3
df['type'] = le.fit_transform(df['type'])# movie is replaced by 1 and tv show is replaced by 0
df['title'] = le.fit_transform(df['title'])
df['country'] = le.fit_transform(df['country'])
df['month_added'] = le.fit_transform(df['month_added'])
df['year_added'] = le.fit_transform(df['year_added'])
df['release_year'] = le.fit_transform(df['release_year'])
df['rating'] = le.fit_transform(df['rating'])
df['duration'] = le.fit_transform(df['duration'])
df['listed_in'] = le.fit_transform(df['listed_in'])

# %%
df
# Out:
#       type  title  country  release_year  rating  duration  listed_in  \
# 0        0   1973      603            72       4       210        273
# 1        1   1089      426            73       8       110        413
# 2        1   2647      603            73       8         0        241
# 3        1   3501      603            73       8         0        296
# 4        1   3855      251            73       8       110        392
# ...    ...    ...      ...           ...     ...       ...        ...
# 8802     0   8757      603            59       5        70        268
# 8803     1   8760      603            70      11       110        423
# 8804     0   8761      603            61       5       206        206
# 8805     0   8764      603            58       3       206        124
# 8806     0   8768      251            67       6        16        327
#
#       year_added  month_added date_added_dates  target_ages
# 0             13           12               25            3
# ...

# %% [markdown]
# # Spliting : training and testing dataset

# %%
y = df.iloc[:,[10]] #target column

# %%
y
# Out:
#       target_ages
# 0               3
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 8802            0
# 8803            2
# 8804            0
# 8805            2
# 8806            3
#
# [8794 rows x 1 columns]

# %%
df.drop(df.columns[10], axis=1, inplace=True)

# %%
x=df

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split
xtr,xts,ytr,yts = train_test_split(x,y,test_size=0.2,random_state=101)

# %%
#import Algorithm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

knn=KNeighborsClassifier(n_neighbors=9)
knn.fit(xtr,ytr)
pred=knn.predict(xts)
res1=accuracy_score(yts,pred)

print("K Nearest Neighbors Top 5 Success Rates is:" , "{:.2f}%".format(100*res1))
print(classification_report(yts,pred))
# Out:
# K Nearest Neighbors Top 5 Success Rates is: 48.15%
#               precision    recall  f1-score   support
#
#            0       0.52      0.74      0.61       838
#            1       0.26      0.13      0.17        94
#            2       0.38      0.18      0.24       293
#            3       0.42      0.30      0.35       534
#
#     accuracy                           0.48      1759
#    macro avg       0.39      0.34      0.34      1759
# weighted avg       0.45      0.48      0.45      1759

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier()
rf.fit(xtr,ytr)
pred1=rf.predict(xts)
res2=accuracy_score(yts,pred1)

print("Random Forest Classifier Success Rate is :", "{:.2f}%".format(100*res2))
print(classification_report(pred1,yts))
# Out:
# Random Forest Classifier Success Rate is : 99.60%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       839
#            1       0.97      1.00      0.98        91
#            2       1.00      0.98      0.99       297
#            3       1.00      1.00      1.00       532
#
#     accuracy                           1.00      1759
#    macro avg       0.99      1.00      0.99      1759
# weighted avg       1.00      1.00      1.00      1759

# %%
from sklearn.tree import DecisionTreeClassifier
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()
clf.fit(xtr,ytr)
pred3=clf.predict(xts)
res4=accuracy_score(pred3,yts)

print("Decision Tree Classifier Success Rate is :", "{:.2f}%".format(100*res4))
print(classification_report(pred3,yts))
# Out:
# Decision Tree Classifier Success Rate is : 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       838
#            1       1.00      1.00      1.00        94
#            2       1.00      1.00      1.00       293
#            3       1.00      1.00      1.00       534
#
#     accuracy                           1.00      1759
#    macro avg       1.00      1.00      1.00      1759
# weighted avg       1.00      1.00      1.00      1759

# %%
from sklearn.ensemble import AdaBoostClassifier
ad= AdaBoostClassifier()
ad.fit(xtr,ytr)
pred4=ad.predict(xts)
res5=accuracy_score(pred4,yts)

print("AdaBoost Classifier Success Rate is :", "{:.2f}%".format(100*res5))
print(classification_report(pred4,yts))
# Out:
# AdaBoost Classifier Success Rate is : 68.11%
#               precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72       977
#            1       0.10      1.00      0.17         9
#            2       0.00      0.00      0.00         0
#            3       1.00      0.69      0.82       773
#
#     accuracy                           0.68      1759
#    macro avg       0.47      0.59      0.43      1759
# weighted avg       0.87      0.68      0.76      1759

# %%
from sklearn.naive_bayes import GaussianNB
gs=GaussianNB()
gs.fit(xtr,ytr)
pred5=gs.predict(xts)
res6=accuracy_score(pred5,yts)

print("AdaBoost Classifier Success Rate is :", "{:.2f}%".format(100*res6))
print(classification_report(pred5,yts))
# Out:
# AdaBoost Classifier Success Rate is : 66.12%
#               precision    recall  f1-score   support
#
#            0       0.77      0.64      0.70      1010
#            1       0.00      0.00      0.00        10
#            2       0.42      0.71      0.52       173
#            3       0.75      0.70      0.72       566
#
#     accuracy                           0.66      1759
#    macro avg       0.48      0.51      0.49      1759
# weighted avg       0.72      0.66      0.68      1759
